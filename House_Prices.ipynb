# %% [markdown]
# <a href="https://colab.research.google.com/github/PatricioSaavedraV/House-Prices/blob/main/House_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reading dataframe

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Link Kaggle: https://www.kaggle.com/datasets/shree1992/housedata/data

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRKrqz1DWLY6HhPKEhzXBGulCEHeGz04yOoAlxKtThPSqz1ks1BV4_L_eg4H0y8eZqLkJAySoEkSgsb/pub?output=csv')
raw_and_columns = 'Row and columns'
print(f"{raw_and_columns} {df.shape}")
df.head()
# Out:
# Row and columns (4600, 18)
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 0:00:00   313000.0         3       1.50         1340      7912
# 1  2014-05-02 0:00:00  2384000.0         5       2.50         3650      9050
# 2  2014-05-02 0:00:00   342000.0         3       2.00         1930     11947
# 3  2014-05-02 0:00:00   420000.0         3       2.25         2000      8030
# 4  2014-05-02 0:00:00   550000.0         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %% [markdown]
# Columns:
# * date: date
# * price: price of house
# * bedrooms: number of bedrooms
# * bathrooms: number of bathrooms
# * sqft_living: square feet of living
# * sqft_lot: square feet of lot
# * floors: number of floors
# * waterfront: Seaview. 0 = No and 1 = yes.
# * view: view type
# * condition: condition type
# * sqft_above: square feet of above
# * sqft_basement: square feet of above of basement
# * yr_built: year of construction
# * yr_renovated: year of renovation
# * street: address
# * city: city
# * statezip: zonal code
# * country: country

# %% [markdown]
# # initial review

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   int64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %% [markdown]
# ## Preparing the dataframe

# %%
df[['new_date', 'hour']] = df['date'].str.split(' ', expand=True)

df['new_date'] = pd.to_datetime(df['new_date'])
df['year'] = df['new_date'].dt.year
df['month'] = df['new_date'].dt.month
df['day'] = df['new_date'].dt.day

df['hour'] = pd.to_datetime(df['hour']).dt.time

df['year'] = df['year'].astype('int64')
df['month'] = df['month'].astype('int64')
df['day'] = df['day'].astype('int64')

df.head()
# Out:
#                  date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 0:00:00   313000.0         3       1.50         1340      7912
# 1  2014-05-02 0:00:00  2384000.0         5       2.50         3650      9050
# 2  2014-05-02 0:00:00   342000.0         3       2.00         1930     11947
# 3  2014-05-02 0:00:00   420000.0         3       2.25         2000      8030
# 4  2014-05-02 0:00:00   550000.0         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  ...  yr_renovated  \
# 0     1.5           0     0          3  ...          2005
# 1     2.0           0     4          5  ...             0
# 2     1.0           0     0          4  ...             0
# 3     1.0           0     0          4  ...             0
# 4     1.0           0     0          4  ...          1992
#
#                      street       city  statezip country   new_date      hour  \
# ...

# %%
df = df.drop(columns=['date'])
df = df.drop(columns=['new_date'])
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0         3       1.50         1340      7912     1.5           0
# 1  2384000.0         5       2.50         3650      9050     2.0           0
# 2   342000.0         3       2.00         1930     11947     1.0           0
# 3   420000.0         3       2.25         2000      8030     1.0           0
# 4   550000.0         4       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  ...  yr_built  yr_renovated  \
# 0     0          3        1340  ...      1955          2005
# 1     4          5        3370  ...      1921             0
# 2     0          4        1930  ...      1966             0
# 3     0          4        1000  ...      1963             0
# 4     0          4        1140  ...      1976          1992
#
#                      street       city  statezip country      hour  year  \
# ...

# %%
print(df['year'].nunique())
print(df['month'].nunique())
print(df['day'].nunique())
print(df['hour'].nunique())
# Out:
# 1
# 3
# 31
# 1

# %%
# All hour and year data is the same, therefore it does not return a value
df = df.drop(columns=['hour'])
df = df.drop(columns=['year'])
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0         3       1.50         1340      7912     1.5           0
# 1  2384000.0         5       2.50         3650      9050     2.0           0
# 2   342000.0         3       2.00         1930     11947     1.0           0
# 3   420000.0         3       2.25         2000      8030     1.0           0
# 4   550000.0         4       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#                      street       city  statezip country  month  day
# ...

# %%
print(df['country'].nunique())
# Out:
# 1

# %%
# All country data is the same, therefore it does not return a value
df = df.drop(columns=['country'])
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0         3       1.50         1340      7912     1.5           0
# 1  2384000.0         5       2.50         3650      9050     2.0           0
# 2   342000.0         3       2.00         1930     11947     1.0           0
# 3   420000.0         3       2.25         2000      8030     1.0           0
# 4   550000.0         4       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#                      street       city  statezip  month  day
# ...

# %%
df[['state', 'code']] = df['statezip'].str.split(' ', expand=True)
unique_states = df['state'].nunique()
print(unique_states)
# Out:
# 1

# %%
# If we review the zip codes, they all correspond to Washington, therefore it doesn't provide real value.
df = df.drop(columns=['statezip'])
df = df.drop(columns=['state'])
df = df.drop(columns=['code'])
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0         3       1.50         1340      7912     1.5           0
# 1  2384000.0         5       2.50         3650      9050     2.0           0
# 2   342000.0         3       2.00         1930     11947     1.0           0
# 3   420000.0         3       2.25         2000      8030     1.0           0
# 4   550000.0         4       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#                      street       city  month  day
# ...

# %%
unique_cities = df['city'].unique()
print(unique_cities)
# Out:
# ['Shoreline' 'Seattle' 'Kent' 'Bellevue' 'Redmond' 'Maple Valley'
#  'North Bend' 'Lake Forest Park' 'Sammamish' 'Auburn' 'Des Moines'
#  'Bothell' 'Federal Way' 'Kirkland' 'Issaquah' 'Woodinville'
#  'Normandy Park' 'Fall City' 'Renton' 'Carnation' 'Snoqualmie' 'Duvall'
#  'Burien' 'Covington' 'Inglewood-Finn Hill' 'Kenmore' 'Newcastle'
#  'Mercer Island' 'Black Diamond' 'Ravensdale' 'Clyde Hill' 'Algona'
#  'Skykomish' 'Tukwila' 'Vashon' 'Yarrow Point' 'SeaTac' 'Medina'
#  'Enumclaw' 'Snoqualmie Pass' 'Pacific' 'Beaux Arts Village' 'Preston'
#  'Milton']

# %%
unique_cities = df['city'].unique()
label_encoder = LabelEncoder()
df['city_map'] = label_encoder.fit_transform(df['city'])
city_mapping = dict(zip(unique_cities, label_encoder.transform(unique_cities)))
print("city mapping:")
print(city_mapping)
# Out:
# city mapping:
# {'Shoreline': 36, 'Seattle': 35, 'Kent': 18, 'Bellevue': 3, 'Redmond': 31, 'Maple Valley': 21, 'North Bend': 27, 'Lake Forest Park': 20, 'Sammamish': 33, 'Auburn': 1, 'Des Moines': 10, 'Bothell': 5, 'Federal Way': 14, 'Kirkland': 19, 'Issaquah': 16, 'Woodinville': 42, 'Normandy Park': 26, 'Fall City': 13, 'Renton': 32, 'Carnation': 7, 'Snoqualmie': 38, 'Duvall': 11, 'Burien': 6, 'Covington': 9, 'Inglewood-Finn Hill': 15, 'Kenmore': 17, 'Newcastle': 25, 'Mercer Island': 23, 'Black Diamond': 4, 'Ravensdale': 30, 'Clyde Hill': 8, 'Algona': 0, 'Skykomish': 37, 'Tukwila': 40, 'Vashon': 41, 'Yarrow Point': 43, 'SeaTac': 34, 'Medina': 22, 'Enumclaw': 12, 'Snoqualmie Pass': 39, 'Pacific': 28, 'Beaux Arts Village': 2, 'Preston': 29, 'Milton': 24}

# %%
df = df.drop(columns=['city'])
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0         3       1.50         1340      7912     1.5           0
# 1  2384000.0         5       2.50         3650      9050     2.0           0
# 2   342000.0         3       2.00         1930     11947     1.0           0
# 3   420000.0         3       2.25         2000      8030     1.0           0
# 4   550000.0         4       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1340              0      1955          2005
# 1     4          5        3370            280      1921             0
# 2     0          4        1930              0      1966             0
# 3     0          4        1000           1000      1963             0
# 4     0          4        1140            800      1976          1992
#
#                      street  month  day  city_map
# ...

# %%
# In the case of 'street', there are 4525 different addresses, therefore this variable will not be used.
unique_cities = df['street'].nunique()
print(unique_cities)
# Out:
# 4525

# %%
df = df.drop(columns=['street'])
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0         3       1.50         1340      7912     1.5           0
# 1  2384000.0         5       2.50         3650      9050     2.0           0
# 2   342000.0         3       2.00         1930     11947     1.0           0
# 3   420000.0         3       2.25         2000      8030     1.0           0
# 4   550000.0         4       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  month  \
# 0     0          3        1340              0      1955          2005      5
# 1     4          5        3370            280      1921             0      5
# 2     0          4        1930              0      1966             0      5
# 3     0          4        1000           1000      1963             0      5
# 4     0          4        1140            800      1976          1992      5
#
#    day  city_map
# 0    2        36
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          4600 non-null   float64
#  1   bedrooms       4600 non-null   int64
#  2   bathrooms      4600 non-null   float64
#  3   sqft_living    4600 non-null   int64
#  4   sqft_lot       4600 non-null   int64
#  5   floors         4600 non-null   float64
#  6   waterfront     4600 non-null   int64
#  7   view           4600 non-null   int64
#  8   condition      4600 non-null   int64
#  9   sqft_above     4600 non-null   int64
#  10  sqft_basement  4600 non-null   int64
#  11  yr_built       4600 non-null   int64
#  12  yr_renovated   4600 non-null   int64
#  13  month          4600 non-null   int64
#  14  day            4600 non-null   int64
#  15  city_map       4600 non-null   int64
# dtypes: float64(3), int64(13)
# memory usage: 575.1 KB

# %% [markdown]
# ## General analysis

# %%
# Boxplots
f, ax = plt.subplots(4,4,figsize=(15,15))
plt.subplots_adjust(wspace=0.4)
sns.boxplot(df["price"], ax = ax[0,0])
sns.boxplot(df["bedrooms"], ax = ax[0,1])
sns.boxplot(df["bathrooms"], ax = ax[0,2])
sns.boxplot(df["sqft_living"], ax = ax[0,3])
sns.boxplot(df["sqft_lot"], ax = ax[1,0])
sns.boxplot(df["floors"], ax = ax[1,1])
sns.boxplot(df["waterfront"], ax = ax[1,2])
sns.boxplot(df["view"], ax = ax[1,3])
sns.boxplot(df["condition"], ax = ax[2,0])
sns.boxplot(df["sqft_above"], ax = ax[2,1])
sns.boxplot(df["sqft_basement"], ax = ax[2,2])
sns.boxplot(df["yr_built"], ax = ax[2,3])
sns.boxplot(df["yr_renovated"], ax = ax[3,0])
sns.boxplot(df["month"], ax = ax[3,1])
sns.boxplot(df["day"], ax = ax[3,2])
sns.boxplot(df["city_map"], ax = ax[3,3])
# Out:
# <Axes: ylabel='city_map'>

# %% [markdown]
# We can see outliers in columns price, sqft_living, sqft_lot, sqft_above Y sqft_basement.

# %%
 # By convention, outliers correspond to:"
 # outliers <= q1 - 1.5 * irq or  >= q3 + 1.5 * irq
 # where irq = Interquartile range or q3 - q1

def perc_outliers (df):
  for k, v in df.items():
    if v.dtype in ['float64', 'int64']:
      q1 = v.quantile(0.25)
      q3 = v.quantile(0.75)
      irq = q3 - q1
      v_col = v[(v <= q1 - 1.5 * irq) | (v >= q3 + 1.5 * irq)]
      perc = np.shape(v_col)[0] * 100.0 / np.shape(df)[0]
      print(f' Column {k} outliers = {perc:.2f}%')

perc_outliers_df = perc_outliers(df)
# Out:
#  Column price outliers = 5.22%
#  Column bedrooms outliers = 2.57%
#  Column bathrooms outliers = 3.07%
#  Column sqft_living outliers = 2.83%
#  Column sqft_lot outliers = 11.76%
#  Column floors outliers = 0.04%
#  Column waterfront outliers = 100.00%
#  Column view outliers = 100.00%
#  Column condition outliers = 0.13%
#  Column sqft_above outliers = 2.52%
#  Column sqft_basement outliers = 1.78%
#  Column yr_built outliers = 0.00%
#  Column yr_renovated outliers = 0.00%
#  Column month outliers = 0.00%
#  Column day outliers = 0.00%
#  Column city_map outliers = 0.00%

# %% [markdown]
# Now, we can see that the columns with the highest percentage of outliers are: sqft_lot (11.76%) and price (5.22%)
#
# *We do not take into consideration the discrete variables

# %%
def del_outliers(df, columns):
  df_out = df.copy()
  for column in columns:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_out = df_out[(df_out[column] >= lower_bound) & (df_out[column] <= upper_bound)]
  return df_out

# %%
columnas = ['sqft_lot', 'price']
df_out = del_outliers(df, columnas)
df_out.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  313000.0         3       1.50         1340      7912     1.5           0
# 2  342000.0         3       2.00         1930     11947     1.0           0
# 3  420000.0         3       2.25         2000      8030     1.0           0
# 4  550000.0         4       2.50         1940     10500     1.0           0
# 5  490000.0         2       1.00          880      6380     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  month  \
# 0     0          3        1340              0      1955          2005      5
# 2     0          4        1930              0      1966             0      5
# 3     0          4        1000           1000      1963             0      5
# 4     0          4        1140            800      1976          1992      5
# 5     0          3         880              0      1938          1994      5
#
#    day  city_map
# 0    2        36
# ...

# %%
# Boxplots
f, ax = plt.subplots(2,2,figsize=(10,10))
plt.subplots_adjust(wspace=0.4)
sns.boxplot(df["sqft_lot"], ax = ax[0,0])
sns.boxplot(df_out["sqft_lot"], ax = ax[0,1])
sns.boxplot(df["price"], ax = ax[1,0])
sns.boxplot(df_out["price"], ax = ax[1,1])
# Out:
# <Axes: ylabel='price'>

# %%
# Histograms
f, ax = plt.subplots(4,4,figsize=(15,15))
#plt.subplots_adjust(wspace=0.4)
sns.histplot(df_out["price"], ax = ax[0,0], kde=True, stat="density")
sns.histplot(df_out["bedrooms"], ax = ax[0,1], kde=True, stat="density")
sns.histplot(df_out["bathrooms"], ax = ax[0,2], kde=True, stat="density")
sns.histplot(df_out["sqft_living"], ax = ax[0,3], kde=True, stat="density")
sns.histplot(df_out["sqft_lot"], ax = ax[1,0], kde=True, stat="density")
sns.histplot(df_out["floors"], ax = ax[1,1], kde=True, stat="density")
sns.histplot(df_out["waterfront"], ax = ax[1,2], kde=True, stat="density")
sns.histplot(df_out["view"], ax = ax[1,3], kde=True, stat="density")
sns.histplot(df_out["condition"], ax = ax[2,0], kde=True, stat="density")
sns.histplot(df_out["sqft_above"], ax = ax[2,1], kde=True, stat="density")
sns.histplot(df_out["sqft_basement"], ax = ax[2,2], kde=True, stat="density")
sns.histplot(df_out["yr_built"], ax = ax[2,3], kde=True, stat="density")
sns.histplot(df_out["yr_renovated"], ax = ax[3,0], kde=True, stat="density")
sns.histplot(df_out["month"], ax = ax[3,1], kde=True, stat="density")
sns.histplot(df_out["day"], ax = ax[3,2], kde=True, stat="density")
sns.histplot(df_out["city_map"], ax = ax[3,3], kde=True, stat="density")
# Out:
# <Axes: xlabel='city_map', ylabel='Density'>

# %%
# Sesgo
def skew (df):
  for k, v in df.items():
    if v.dtype in ['float64', 'int64']:
      df_skew = v.skew()
      print(f' Coolumn {k} skew = {df_skew:.2f}%')

df_skew = skew(df_out)
# Out:
#  Coolumn price skew = 0.68%
#  Coolumn bedrooms skew = 0.44%
#  Coolumn bathrooms skew = 0.21%
#  Coolumn sqft_living skew = 0.81%
#  Coolumn sqft_lot skew = 0.72%
#  Coolumn floors skew = 0.67%
#  Coolumn waterfront skew = 19.60%
#  Coolumn view skew = 4.06%
#  Coolumn condition skew = 1.02%
#  Coolumn sqft_above skew = 1.09%
#  Coolumn sqft_basement skew = 1.29%
#  Coolumn yr_built skew = -0.43%
#  Coolumn yr_renovated skew = 0.37%
#  Coolumn month skew = 0.35%
#  Coolumn day skew = 0.10%
#  Coolumn city_map skew = -0.86%

# %% [markdown]
# Here, we can see that the variables with the greatest skew are: waterfront (19.6%) and view (4.06%)

# %%
correlation = df_out.corr()
plt.figure(figsize=(15,15))
ax = sns.heatmap(correlation, vmax = 1, square = True, annot = True, cmap ='viridis')
plt.title("Matriz de correlación")
plt.show()

# %% [markdown]
# The variables that have the strongest correlation with price are: sqft_living (0.56), sqft_above(0.46), bathrooms (0.41), bedrooms (0.27), floors (0.25), sqft_basement(0.23), view (0.21) and city_map (0.12)

# %% [markdown]
# However, there are variables that have a high correlation with each other: sqft_above with sqft_living, sqft_living with bathrooms, and sqft_above with bathrooms. Therefore, we should remove 2 of them.

# %%
df_out[["sqft_above","sqft_living","bathrooms","price"]].corr()
# Out:
#              sqft_above  sqft_living  bathrooms     price
# sqft_above     1.000000     0.843287   0.635417  0.461715
# sqft_living    0.843287     1.000000   0.717275  0.559141
# bathrooms      0.635417     0.717275   1.000000  0.408239
# price          0.461715     0.559141   0.408239  1.000000

# %% [markdown]
# We will only use sqft_living

# %%
new_columns = ['sqft_living', 'sqft_above', 'floors', 'sqft_basement', 'view', 'city_map', 'price']
copy_df = df[new_columns].copy()
copy_df.head()
# Out:
#    sqft_living  sqft_above  floors  sqft_basement  view  city_map      price
# 0         1340        1340     1.5              0     0        36   313000.0
# 1         3650        3370     2.0            280     4        35  2384000.0
# 2         1930        1930     1.0              0     0        18   342000.0
# 3         2000        1000     1.0           1000     0         3   420000.0
# 4         1940        1140     1.0            800     0        31   550000.0
